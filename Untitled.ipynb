# %%
import pandas as pd

# %%
df = pd.read_json('./WEEK8/strava_simplified.json')

# %%
df.describe()
# Out:
#        resource_state     distance  moving_time  elapsed_time  \
# count             5.0     5.000000     5.000000      5.000000
# mean              2.0  7349.860000  1332.200000   1698.800000
# std               0.0   528.554461   163.484556    618.279629
# min               2.0  6937.300000  1188.000000   1200.000000
# 25%               2.0  7000.000000  1200.000000   1345.000000
# 50%               2.0  7000.000000  1255.000000   1500.000000
# 75%               2.0  7701.200000  1500.000000   1694.000000
# max               2.0  8110.800000  1518.000000   2755.000000
#
#        total_elevation_gain  workout_type            id  utc_offset  \
# count              5.000000           5.0  5.000000e+00         5.0
# mean              22.260000          10.0  7.980403e+09     10800.0
# std               21.299366           0.0  4.118764e+06         0.0
# min                0.000000          10.0  7.975610e+09     10800.0
# ...

# %%
df.columns
# Out:
# Index(['resource_state', 'athlete', 'name', 'distance', 'moving_time',
#        'elapsed_time', 'total_elevation_gain', 'type', 'sport_type',
#        'workout_type', 'id', 'start_date', 'start_date_local', 'timezone',
#        'utc_offset', 'location_city', 'location_state', 'location_country',
#        'achievement_count', 'kudos_count', 'comment_count', 'athlete_count',
#        'photo_count', 'map', 'trainer', 'commute', 'manual', 'private',
#        'visibility', 'flagged', 'gear_id', 'start_latlng', 'end_latlng',
#        'average_speed', 'max_speed', 'has_heartrate', 'heartrate_opt_out',
#        'display_hide_heartrate_option', 'elev_high', 'elev_low', 'upload_id',
#        'upload_id_str', 'external_id', 'from_accepted_tag', 'pr_count',
#        'total_photo_count', 'has_kudoed'],
#       dtype='object')

# %%
distance = df['distance']

# %%
distance
# Out:
# 0    8110.8
# 1    7000.0
# 2    6937.3
# 3    7701.2
# 4    7000.0
# Name: distance, dtype: float64

# %%
df
# Out:
#    resource_state                                athlete             name  \
# 0               2  {'id': 17111048, 'resource_state': 1}     Morning Ride
# 1               2  {'id': 17111048, 'resource_state': 1}  From the office
# 2               2  {'id': 17111048, 'resource_state': 1}     Morning Ride
# 3               2  {'id': 17111048, 'resource_state': 1}   Afternoon Ride
# 4               2  {'id': 17111048, 'resource_state': 1}    To the office
#
#    distance  moving_time  elapsed_time  total_elevation_gain  type sport_type  \
# 0    8110.8         1518          2755                  45.7  Ride       Ride
# 1    7000.0         1200          1200                   0.0  Ride       Ride
# 2    6937.3         1188          1345                  27.7  Ride       Ride
# 3    7701.2         1255          1694                  37.9  Ride       Ride
# 4    7000.0         1500          1500                   0.0  Ride       Ride
#
# ...
